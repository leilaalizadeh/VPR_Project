# %% [markdown]
# # Start coding and Enjoy the journey

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/MyDrive/VPR_Project
# Out:
# /content/drive/.shortcut-targets-by-id/13HgKMxHOXBgzaYaUjIY_1zQjq7W2sta1/VPR_Project

# %% [markdown]
# # **Threshold**

# %%
path = '/content/drive/MyDrive/VPR_Project/logs/log_dir/'

# %% [markdown]
# # **SVOX_Night - Train DataSet**

# %%
# !python threshold.py \
  --z_path {path}'/svox_night_train_megaloc/z_data.torch'\
  --matches_dir {path}'/svox_night_train_megaloc/preds_loftr'\
  --dataset_name svox_night_train_megaloc_loftr \
  --t_rerank 3.73 \
  --t_retrieval 0.0 \
  --threshold_mode quantiles\
  --plots_dir {path}'/svox_night_train_megaloc/plots_loftr'
# Out:
# [svox_night_train_megaloc_loftr]
# Retrieval-only: R@1=91.17  R@5=95.73  R@10=97.44  R@20=98.43
# Always-rerank:  R@1=87.46  R@5=95.58  R@10=97.29  R@20=98.43
# Inliers(top1): min=5.0, median=31.0, max=498.0
#
# Best threshold (max R@1):
#   t = 5.00
#   Adaptive: R@1=91.17 R@5=95.73 @10=97.44 R@20=98.43
#   % reranked    = 0.0
#   Estimated time/query = 0.000s (always-rerank: 3.730s)

# %%
# !python threshold.py \
  --z_path  {path}'/svox_night_train_megaloc/z_data.torch'\
  --matches_dir {path}'/svox_night_train_megaloc/preds_superglue'\
  --dataset_name svox_night_train_megaloc_superglue\
  --t_rerank 1.33 \
  --t_retrieval 0.0 \
  --threshold_mode quantiles\
  --plots_dir {path}'/svox_night_train_megaloc/plots_superglue'
# Out:
# [svox_night_train_megaloc_superglue]
# Retrieval-only: R@1=91.17  R@5=95.73  R@10=97.44  R@20=98.43
# Always-rerank:  R@1=86.89  R@5=95.87  R@10=97.72  R@20=98.43
# Inliers(top1): min=0.0, median=19.0, max=118.0
#
# Best threshold (max R@1):
#   t = 6.10
#   Adaptive: R@1=92.45 R@5=96.15 @10=97.72 R@20=98.43
#   % reranked    = 10.1
#   Estimated time/query = 0.135s (always-rerank: 1.330s)

# %%
# !python threshold.py \
  --z_path {path}'/svox_night_train_netvlad/z_data.torch'\
  --matches_dir {path}'/svox_night_train_netvlad/preds_loftr'\
  --dataset_name svox_night_train_netvlad_loftr\
  --t_rerank 3.73 \
  --t_retrieval 0.0 \
  --threshold_mode quantiles\
  --plots_dir {path}'/svox_night_train_netvlad/plots_loftr'
# Out:
# [svox_night_train_netvlad_loftr]
# Retrieval-only: R@1=3.13  R@5=8.97  R@10=12.11  R@20=17.81
# Always-rerank:  R@1=13.68  R@5=15.24  R@10=16.24  R@20=17.81
# Inliers(top1): min=5.0, median=8.0, max=406.0
#
# Best threshold (max R@1):
#   t = 406.00
#   Adaptive: R@1=13.68 R@5=15.24 @10=16.24 R@20=17.81
#   % reranked    = 99.9
#   Estimated time/query = 3.725s (always-rerank: 3.730s)

# %%
# !python threshold.py \
  --z_path  {path}'/svox_night_train_netvlad/z_data.torch'\
  --matches_dir  {path}'/svox_night_train_netvlad/preds_superglue'\
  --dataset_name svox_night_train_netvlad_superglue\
  --t_rerank 1.33 \
  --t_retrieval 0.0 \
  --threshold_mode quantiles\
  --plots_dir {path}'/svox_night_train_netvlad/plots_superglue'
# Out:
# [svox_night_train_netvlad_superglue]
# Retrieval-only: R@1=3.13  R@5=8.97  R@10=12.11  R@20=17.81
# Always-rerank:  R@1=13.25  R@5=15.10  R@10=16.52  R@20=17.81
# Inliers(top1): min=0.0, median=6.0, max=77.0
#
# Best threshold (max R@1):
#   t = 15.00
#   Adaptive: R@1=13.39 R@5=14.96 @10=16.38 R@20=17.81
#   % reranked    = 97.2
#   Estimated time/query = 1.292s (always-rerank: 1.330s)

# %% [markdown]
# # **SVOX_Sun Train DataSet**

# %%
# !python threshold.py \
  --z_path {path}'/svox_sun_train_megaloc/z_data.torch'\
  --matches_dir {path}'/svox_sun_train_megaloc/preds_loftr'\
  --dataset_name svox_sun_train_megaloc_loftr \
  --t_rerank 3.73 \
  --t_retrieval 0.0 \
  --threshold_mode quantiles\
  --plots_dir {path}'/svox_sun_train_megaloc/plots_loftr'
# Out:
# [svox_sun_train_megaloc_loftr]
# Retrieval-only: R@1=94.52  R@5=97.89  R@10=98.31  R@20=98.60
# Always-rerank:  R@1=93.26  R@5=96.49  R@10=97.75  R@20=98.60
# Inliers(top1): min=2.0, median=83.0, max=649.0
#
# Best threshold (max R@1):
#   t = 2.00
#   Adaptive: R@1=94.52 R@5=97.89 @10=98.31 R@20=98.60
#   % reranked    = 0.0
#   Estimated time/query = 0.000s (always-rerank: 3.730s)

# %%
# !python threshold.py \
  --z_path  {path}'/svox_sun_train_megaloc/z_data.torch'\
  --matches_dir {path}'/svox_sun_train_megaloc/preds_superglue'\
  --dataset_name svox_sun_train_megaloc_superglue\
  --t_rerank 1.33 \
  --t_retrieval 0.0 \
  --threshold_mode quantiles\
  --plots_dir {path}'/svox_sun_train_megaloc/plots_superglue'
# Out:
# [svox_sun_train_megaloc_superglue]
# Retrieval-only: R@1=94.52  R@5=97.89  R@10=98.31  R@20=98.60
# Always-rerank:  R@1=90.59  R@5=96.21  R@10=97.19  R@20=98.60
# Inliers(top1): min=0.0, median=25.0, max=175.0
#
# Best threshold (max R@1):
#   t = 0.00
#   Adaptive: R@1=94.52 R@5=97.89 @10=98.31 R@20=98.60
#   % reranked    = 0.0
#   Estimated time/query = 0.000s (always-rerank: 1.330s)

# %%
# !python threshold.py \
  --z_path {path}'/svox_sun_train_netvlad/z_data.torch'\
  --matches_dir {path}'/svox_sun_train_netvlad/preds_loftr'\
  --dataset_name svox_sun_train_netvlad_loftr\
  --t_rerank 3.73 \
  --t_retrieval 0.0 \
  --threshold_mode quantiles\
  --plots_dir {path}'/svox_sun_train_netvlad/plots_loftr'
# Out:
# [svox_sun_train_netvlad_loftr]
# Retrieval-only: R@1=27.11  R@5=40.73  R@10=46.21  R@20=51.40
# Always-rerank:  R@1=48.74  R@5=50.00  R@10=50.84  R@20=51.40
# Inliers(top1): min=0.0, median=11.0, max=419.0
#
# Best threshold (max R@1):
#   t = 134.00
#   Adaptive: R@1=48.74 R@5=50.00 @10=50.84 R@20=51.40
#   % reranked    = 82.3
#   Estimated time/query = 3.070s (always-rerank: 3.730s)

# %%
# !python threshold.py \
  --z_path {path}'/svox_sun_train_netvlad/z_data.torch'\
  --matches_dir  {path}'/svox_sun_train_netvlad/preds_superglue'\
  --dataset_name svox_sun_train_netvlad_superglue\
  --t_rerank 1.33 \
  --t_retrieval 0.0 \
  --threshold_mode quantiles\
  --plots_dir {path}'/svox_sun_train_netvlad/plots_superglue'
# Out:
# [svox_sun_train_netvlad_superglue]
# Retrieval-only: R@1=27.11  R@5=40.73  R@10=46.21  R@20=51.40
# Always-rerank:  R@1=46.91  R@5=49.86  R@10=50.70  R@20=51.40
# Inliers(top1): min=0.0, median=7.0, max=125.0
#
# Best threshold (max R@1):
#   t = 44.12
#   Adaptive: R@1=46.91 R@5=49.86 @10=50.70 R@20=51.40
#   % reranked    = 87.5
#   Estimated time/query = 1.164s (always-rerank: 1.330s)

# %% [markdown]
# # **SF - Validation DataSet**

# %%
# !python threshold.py \
  --z_path {path}'/sf_val_netvlad/z_data.torch' \
  --matches_dir {path}'/sf_val_netvlad/preds_loftr' \
  --dataset_name sf_validation_netvlad_loftr \
  --t_rerank 3.73 \
  --t_retrieval 0.0 \
  --threshold_mode quantiles\
  --plots_dir {path}'/sf_val_netvlad/plots_loftr'
# Out:
# [sf_validation_netvlad_loftr]
# Retrieval-only: R@1=53.22  R@5=67.55  R@10=73.33  R@20=78.98
# Always-rerank:  R@1=72.85  R@5=75.82  R@10=77.36  R@20=78.98
# Inliers(top1): min=5.0, median=37.0, max=2327.0
#
# Best threshold (max R@1):
#   t = 132.00
#   Adaptive: R@1=72.89 R@5=75.82 @10=77.36 R@20=78.98
#   % reranked    = 62.4
#   Estimated time/query = 2.328s (always-rerank: 3.730s)

# %%
# !python threshold.py \
  --z_path {path}'/sf_val_netvlad/z_data.torch' \
  --matches_dir {path}'/sf_val_netvlad/preds_superglue' \
  --dataset_name sf_validation_netvlad_superglue \
  --t_rerank 1.33 \
  --t_retrieval 0.0 \
  --threshold_mode quantiles\
  --plots_dir {path}'/sf_val_netvlad/plots_superglue'
# Out:
# [sf_validation_netvlad_superglue]
# Retrieval-only: R@1=53.22  R@5=67.55  R@10=73.33  R@20=78.98
# Always-rerank:  R@1=70.81  R@5=75.42  R@10=77.10  R@20=78.98
# Inliers(top1): min=0.0, median=9.0, max=190.0
#
# Best threshold (max R@1):
#   t = 19.00
#   Adaptive: R@1=70.84 R@5=75.39 @10=77.09 R@20=78.98
#   % reranked    = 64.9
#   Estimated time/query = 0.864s (always-rerank: 1.330s)

# %%
# !python threshold.py \
  --z_path {path}'/sf_val_megaloc/z_data.torch' \
  --matches_dir {path}'sf_val_megaloc/preds_loftr' \
  --dataset_name sf_validation_megaloc_loftr \
  --t_rerank 3.73 \
  --t_retrieval 0.0 \
  --threshold_mode quantiles\
  --plots_dir {path}'/sf_val_megaloc/plots_loftr'
# Out:
# [sf_validation_megaloc_loftr]
# Retrieval-only: R@1=97.26  R@5=98.92  R@10=99.22  R@20=99.41
# Always-rerank:  R@1=92.89  R@5=97.34  R@10=98.59  R@20=99.41
# Inliers(top1): min=5.0, median=149.0, max=2328.0
#
# Best threshold (max R@1):
#   t = 5.00
#   Adaptive: R@1=97.26 R@5=98.92 @10=99.22 R@20=99.41
#   % reranked    = 0.0
#   Estimated time/query = 0.000s (always-rerank: 3.730s)

# %%
# !python threshold.py \
  --z_path {path}'/sf_val_megaloc/z_data.torch' \
  --matches_dir {path}'/sf_val_megaloc/preds_superglue' \
  --dataset_name sf_validation_megaloc_superglue \
  --t_rerank 1.33 \
  --t_retrieval 0.0 \
  --threshold_mode quantiles\
  --plots_dir {path}'/sf_val_megaloc/plots_superglue'
# Out:
# [sf_validation_megaloc_superglue]
# Retrieval-only: R@1=97.26  R@5=98.92  R@10=99.22  R@20=99.41
# Always-rerank:  R@1=91.33  R@5=97.72  R@10=98.87  R@20=99.41
# Inliers(top1): min=0.0, median=19.0, max=191.0
#
# Best threshold (max R@1):
#   t = 0.00
#   Adaptive: R@1=97.26 R@5=98.92 @10=99.22 R@20=99.41
#   % reranked    = 0.0
#   Estimated time/query = 0.000s (always-rerank: 1.330s)

# %% [markdown]
# # **Tokyo - Test DataSets**

# %%
base=f"{path}/tokyo_test_megaloc"
# !python threshold.py \
  --z_path "$base/z_data.torch" \
  --matches_dir "$base/preds_loftr" \
  --dataset_name Tokyo_test_megaloc_loftr \
  --t_rerank 3.73 \
  --t_retrieval 0.0 \
  --threshold_mode quantiles\
  --fixed_threshold 5\
  --plots_dir "$base/plots_threshold_loftr"
# Out:
# Fixed threshold evaluation:
#   t = 5.00
#   Adaptive: R@1=94.92 R@5=97.46 R@10=98.41 R@20=99.05
#   % reranked    = 0.0
#   Estimated time/query = 0.000s (always-rerank: 3.730s)

# %%
base=f"{path}/tokyo_test_megaloc"
# !python threshold.py \
  --z_path "$base/z_data.torch" \
  --matches_dir "$base/preds_superglue" \
  --dataset_name Tokyo_test_megaloc_superglue \
  --t_rerank 3.73 \
  --t_retrieval 0.0 \
  --threshold_mode quantiles\
  --fixed_threshold 6\
  --plots_dir "$base/plots_threshold_superglue"
# Out:
# Fixed threshold evaluation:
#   t = 6.00
#   Adaptive: R@1=95.24 R@5=98.10 R@10=98.73 R@20=99.05
#   % reranked    = 5.4
#   Estimated time/query = 0.201s (always-rerank: 3.730s)

# %%
base=f"{path}/tokyo_test_netvlad"
# !python threshold.py \
  --z_path "$base/z_data.torch" \
  --matches_dir "$base/preds_loftr" \
  --dataset_name Tokyo_test_netvlad_loftr \
  --t_rerank 3.73 \
  --t_retrieval 0.0 \
  --threshold_mode quantiles\
  --fixed_threshold 132\
  --plots_dir "$base/plots_threshold_loftr"
# Out:
# Fixed threshold evaluation:
#   t = 132.00
#   Adaptive: R@1=68.57 R@5=72.70 R@10=73.65 R@20=78.73
#   % reranked    = 77.8
#   Estimated time/query = 2.901s (always-rerank: 3.730s)

# %%
base=f"{path}/tokyo_test_netvlad"
# !python threshold.py \
  --z_path "$base/z_data.torch" \
  --matches_dir "$base/preds_superglue" \
  --dataset_name Tokyo_test_netvlad_superglue \
  --t_rerank 3.73 \
  --t_retrieval 0.0 \
  --threshold_mode quantiles\
  --fixed_threshold 19\
  --plots_dir "$base/plots_threshold_superglue"
# Out:
# Fixed threshold evaluation:
#   t = 19.00
#   Adaptive: R@1=69.21 R@5=72.38 R@10=74.60 R@20=78.73
#   % reranked    = 68.9
#   Estimated time/query = 2.570s (always-rerank: 3.730s)

# %% [markdown]
# # **SF - Test DataSet**

# %%
base=f"{path}/sf_test_megaloc"
# !python threshold.py \
  --z_path "$base/z_data.torch" \
  --matches_dir "$base/preds_loftr" \
  --dataset_name sf_test_megaloc_loftr \
  --t_rerank 3.73 \
  --t_retrieval 0.0 \
  --threshold_mode quantiles\
  --fixed_threshold 5\
  --plots_dir "$base/plots_threshold_loftr"
# Out:
# Fixed threshold evaluation:
#   t = 5.00
#   Adaptive: R@1=86.70 R@5=89.90 R@10=90.80 R@20=91.30
#   % reranked    = 0.0
#   Estimated time/query = 0.000s (always-rerank: 3.730s)

# %%
base=f"{path}/sf_test_megaloc"
# !python threshold.py \
  --z_path "$base/z_data.torch" \
  --matches_dir "$base/preds_superglue" \
  --dataset_name sf_test_megaloc_superglue \
  --t_rerank 3.73 \
  --t_retrieval 0.0 \
  --threshold_mode quantiles\
  --fixed_threshold 6\
  --plots_dir "$base/plots_threshold_superglue"
# Out:
# Fixed threshold evaluation:
#   t = 6.00
#   Adaptive: R@1=86.40 R@5=89.50 R@10=90.60 R@20=91.30
#   % reranked    = 7.9
#   Estimated time/query = 0.295s (always-rerank: 3.730s)

# %%
base=f"{path}/sf_test_netvlad"
# !python threshold.py \
  --z_path "$base/z_data.torch" \
  --matches_dir "$base/preds_loftr" \
  --dataset_name sf_test_netvlad_loftr \
  --t_rerank 3.73 \
  --t_retrieval 0.0 \
  --threshold_mode quantiles\
  --fixed_threshold 132\
  --plots_dir "$base/plots_threshold_loftr"
# Out:
# Fixed threshold evaluation:
#   t = 132.00
#   Adaptive: R@1=53.60 R@5=55.30 R@10=55.80 R@20=56.20
#   % reranked    = 83.4
#   Estimated time/query = 3.111s (always-rerank: 3.730s)

# %%
base=f"{path}/sf_test_netvlad"
# !python threshold.py \
  --z_path "$base/z_data.torch" \
  --matches_dir "$base/preds_superglue" \
  --dataset_name sf_test_netvlad_superglue \
  --t_rerank 3.73 \
  --t_retrieval 0.0 \
  --threshold_mode quantiles\
  --fixed_threshold 19\
  --plots_dir "$base/plots_threshold_superglu"
# Out:
# Fixed threshold evaluation:
#   t = 19.00
#   Adaptive: R@1=52.60 R@5=55.10 R@10=56.00 R@20=56.20
#   % reranked    = 82.7
#   Estimated time/query = 3.085s (always-rerank: 3.730s)

# %% [markdown]
# # **SVOX-night - Test DataSet**

# %%
base=f"{path}/svox_night_test_megaloc"
# !python threshold.py \
  --z_path "$base/z_data.torch" \
  --matches_dir "$base/preds_loftr" \
  --dataset_name Tsvox_night_test_megaloc_loftr \
  --t_rerank 3.73 \
  --t_retrieval 0.0 \
  --threshold_mode quantiles\
  --fixed_threshold 5\
  --plots_dir "$base/plots_threshold_loftr"
# Out:
# Fixed threshold evaluation:
#   t = 5.00
#   Adaptive: R@1=95.14 R@5=98.06 R@10=98.78 R@20=99.15
#   % reranked    = 0.0
#   Estimated time/query = 0.000s (always-rerank: 3.730s)

# %%
base=f"{path}/svox_night_test_megaloc"
# !python threshold.py \
  --z_path "$base/z_data.torch" \
  --matches_dir "$base/preds_superglue" \
  --dataset_name svox_night_test_megaloc_superglue \
  --t_rerank 3.73 \
  --t_retrieval 0.0 \
  --threshold_mode quantiles\
  --fixed_threshold 6\
  --plots_dir "$base/plots_threshold_superglue"
# Out:
# Fixed threshold evaluation:
#   t = 6.00
#   Adaptive: R@1=94.65 R@5=97.69 R@10=98.66 R@20=99.15
#   % reranked    = 3.6
#   Estimated time/query = 0.136s (always-rerank: 3.730s)

# %%
base=f"{path}/svox_night_test_netvlad"
# !python threshold.py \
  --z_path "$base/z_data.torch" \
  --matches_dir "$base/preds_loftr" \
  --dataset_name svox_night_test_netvlad_loftr \
  --t_rerank 3.73 \
  --t_retrieval 0.0 \
  --threshold_mode quantiles\
  --fixed_threshold 132\
  --plots_dir "$base/plots_threshold_loftr"
# Out:
# Fixed threshold evaluation:
#   t = 132.00
#   Adaptive: R@1=25.64 R@5=27.83 R@10=28.55 R@20=29.65
#   % reranked    = 96.4
#   Estimated time/query = 3.594s (always-rerank: 3.730s)

# %%
base=f"{path}/svox_night_test_netvlad"
# !python threshold.py \
  --z_path "$base/z_data.torch" \
  --matches_dir "$base/preds_superglue" \
  --dataset_name svox_night_test_netvlad_superglue \
  --t_rerank 3.73 \
  --t_retrieval 0.0 \
  --threshold_mode quantiles\
  --fixed_threshold 19\
  --plots_dir "$base/plots_threshold_superglue"
# Out:
# Fixed threshold evaluation:
#   t = 19.00
#   Adaptive: R@1=24.54 R@5=26.85 R@10=27.83 R@20=29.65
#   % reranked    = 93.1
#   Estimated time/query = 3.472s (always-rerank: 3.730s)

# %% [markdown]
# # **SVOX_Sun - Test DataSets**

# %%
base=f"{path}/svox_sun_test_megaloc"
# !python threshold.py \
  --z_path "$base/z_data.torch" \
  --matches_dir "$base/preds_loftr" \
  --dataset_name svox_sun_test_megaloc_loftr \
  --t_rerank 3.73 \
  --t_retrieval 0.0 \
  --threshold_mode quantiles\
  --fixed_threshold 5\
  --plots_dir "$base/plots_threshold_loftr"
# Out:
# Fixed threshold evaluation:
#   t = 5.00
#   Adaptive: R@1=96.49 R@5=99.41 R@10=99.65 R@20=99.65
#   % reranked    = 0.1
#   Estimated time/query = 0.004s (always-rerank: 3.730s)

# %%
base=f"{path}/svox_sun_test_megaloc"
# !python threshold.py \
  --z_path "$base/z_data.torch" \
  --matches_dir "$base/preds_superglue" \
  --dataset_name svox_sun_test_megaloc_superglue \
  --t_rerank 3.73 \
  --t_retrieval 0.0 \
  --threshold_mode quantiles\
  --fixed_threshold 6\
  --plots_dir "$base/plots_threshold_superglue"
# Out:
# Fixed threshold evaluation:
#   t = 6.00
#   Adaptive: R@1=95.90 R@5=99.30 R@10=99.65 R@20=99.65
#   % reranked    = 1.5
#   Estimated time/query = 0.057s (always-rerank: 3.730s)

# %%
base=f"{path}/svox_sun_test_netvlad"
# !python threshold.py \
  --z_path "$base/z_data.torch" \
  --matches_dir "$base/preds_loftr" \
  --dataset_name svox_sun_test_netvlad_loftr \
  --t_rerank 3.73 \
  --t_retrieval 0.0 \
  --threshold_mode quantiles\
  --fixed_threshold 132\
  --plots_dir "$base/plots_threshold_loftr"
# Out:
# Fixed threshold evaluation:
#   t = 132.00
#   Adaptive: R@1=61.48 R@5=63.47 R@10=64.52 R@20=65.81
#   % reranked    = 73.7
#   Estimated time/query = 2.747s (always-rerank: 3.730s)

# %%
base=f"{path}/svox_sun_test_netvlad"
# !python threshold.py \
  --z_path "$base/z_data.torch" \
  --matches_dir "$base/preds_superglue" \
  --dataset_name svox_sun_test_netvlad_superglue \
  --t_rerank 3.73 \
  --t_retrieval 0.0 \
  --threshold_mode quantiles\
  --fixed_threshold 19\
  --plots_dir "$base/plots_threshold_superglue"
# Out:
# Fixed threshold evaluation:
#   t = 19.00
#   Adaptive: R@1=60.30 R@5=63.23 R@10=64.40 R@20=65.81
#   % reranked    = 67.0
#   Estimated time/query = 2.498s (always-rerank: 3.730s)

# %% [markdown]
# # **Logestic**

# %% [markdown]
# # **SF - Test Dataset**

# %%
# !python -u logistic.py \
  --name "NetVLAD+SuperGlue (sf)" \
  --train_z_path {path}"/svox_night_train_netvlad/z_data.torch" \
  --train_matches_dir {path}"/svox_night_train_netvlad/preds_superglue" \
  --train2_z_path {path}"/svox_sun_train_netvlad/z_data.torch" \
  --train2_matches_dir {path}"/svox_sun_train_netvlad/preds_superglue" \
  --val_z_path {path}"/sf_val_netvlad/z_data.torch" \
  --val_matches_dir {path}"/sf_val_netvlad/preds_superglue" \
  --test_z_path {path}"/sf_test_netvlad/z_data.torch" \
  --test_matches_dir {path}"/sf_test_netvlad/preds_superglue" \
  --t_rerank 3.78 \
  --t_retrieval 0.0 \
  --plot\
  --plots_dir {path}'/sf_test_netvlad/plots_log_superglue'
# Out:
# === VALIDATION (fixed p0* chosen on VAL) ===
# [NetVLAD+SuperGlue (sf)] VAL AUPRC - Uncertainty = 0.950
# Random baseline (positive rate) = 0.4677843112723633
# Chosen cutoff p0*: 0.470  (eps=0.001, based on R@1)
#
# [NetVLAD+SuperGlue (sf) VAL]
# Retrieval-only: R@1=53.22  R@5=67.55  R@10=73.33  R@20=78.98
# Always-rerank:  R@1=70.81  R@5=75.42  R@10=77.10  R@20=78.98
# Adaptive:       R@1=70.89  R@5=75.38  R@10=77.09  R@20=78.98
# % reranked: 55.1
# Est. time/query: 2.085s (always-rerank: 3.780s)
#
# === TEST (using p0* from VAL) ===
# [NetVLAD+SuperGlue (sf)] TEST AUPRC - Uncertainty = 0.989
# Random baseline (positive rate) = 0.728
#
# [NetVLAD+SuperGlue (sf) TEST]
# Retrieval-only: R@1=27.20  R@5=43.80  R@10=50.30  R@20=56.20
# Always-rerank:  R@1=52.60  R@5=55.10  R@10=56.00  R@20=56.20
# Adaptive:       R@1=52.30  R@5=55.10  R@10=56.00  R@20=56.20
# % reranked: 77.6
# Est. time/query: 2.933s (always-rerank: 3.780s)
# Wrong rate VAL : 0.4677843112723633
# ...

# %%
# !python -u logistic.py \
  --name "NetVLAD+LoFTR (sf)" \
  --train_z_path {path}"/svox_night_train_netvlad/z_data.torch" \
  --train_matches_dir {path}"/svox_night_train_netvlad/preds_loftr" \
  --train2_z_path {path}"/svox_sun_train_netvlad/z_data.torch" \
  --train2_matches_dir {path}"/svox_sun_train_netvlad/preds_loftr" \
  --val_z_path {path}"/sf_val_netvlad/z_data.torch" \
  --val_matches_dir {path}"/sf_val_netvlad/preds_loftr" \
  --test_z_path {path}"/sf_test_netvlad/z_data.torch" \
  --test_matches_dir {path}"/sf_test_netvlad/preds_loftr" \
  --t_rerank 3.78 \
  --t_retrieval 0.0 \
  --plot\
  --plots_dir {path}'/sf_test_netvlad/plots_log_loftr'
# Out:
# === VALIDATION (fixed p0* chosen on VAL) ===
# [NetVLAD+LoFTR (sf)] VAL AUPRC - Uncertainty = 0.953
# Random baseline (positive rate) = 0.4677843112723633
# Chosen cutoff p0*: 0.020  (eps=0.001, based on R@1)
#
# [NetVLAD+LoFTR (sf) VAL]
# Retrieval-only: R@1=53.22  R@5=67.55  R@10=73.33  R@20=78.98
# Always-rerank:  R@1=72.85  R@5=75.82  R@10=77.36  R@20=78.98
# Adaptive:       R@1=72.78  R@5=75.82  R@10=77.36  R@20=78.98
# % reranked: 53.8
# Est. time/query: 2.035s (always-rerank: 3.780s)
#
# === TEST (using p0* from VAL) ===
# [NetVLAD+LoFTR (sf)] TEST AUPRC - Uncertainty = 0.990
# Random baseline (positive rate) = 0.728
#
# [NetVLAD+LoFTR (sf) TEST]
# Retrieval-only: R@1=27.20  R@5=43.80  R@10=50.30  R@20=56.20
# Always-rerank:  R@1=53.60  R@5=55.30  R@10=55.80  R@20=56.20
# Adaptive:       R@1=53.50  R@5=55.20  R@10=55.80  R@20=56.20
# % reranked: 77.6
# Est. time/query: 2.933s (always-rerank: 3.780s)

# %%
# !python -u logistic.py \
  --name "MegaLoc+SuperGlue (sf)" \
  --train_z_path {path}"/svox_night_train_megaloc/z_data.torch" \
  --train_matches_dir {path}"/svox_night_train_megaloc/preds_superglue" \
  --train2_z_path {path}"/svox_sun_train_megaloc/z_data.torch" \
  --train2_matches_dir {path}"/svox_sun_train_megaloc/preds_superglue" \
  --val_z_path {path}"/sf_val_megaloc/z_data.torch" \
  --val_matches_dir {path}"/sf_val_megaloc/preds_superglue" \
  --test_z_path {path}"/sf_test_megaloc/z_data.torch" \
  --test_matches_dir {path}"/sf_test_megaloc/preds_superglue" \
  --t_rerank 3.78 \
  --t_retrieval 0.0 \
  --plot\
  --plots_dir {path}'/sf_test_megaloc/plots_log_superglue'
# Out:
# === VALIDATION (fixed p0* chosen on VAL) ===
# [MegaLoc+SuperGlue (sf)] VAL AUPRC - Uncertainty = 0.426
# Random baseline (positive rate) = 0.027398974102339546
# Chosen cutoff p0*: 0.920  (eps=0.001, based on R@1)
#
# [MegaLoc+SuperGlue (sf) VAL]
# Retrieval-only: R@1=97.26  R@5=98.92  R@10=99.22  R@20=99.41
# Always-rerank:  R@1=91.33  R@5=97.72  R@10=98.87  R@20=99.41
# Adaptive:       R@1=97.26  R@5=98.92  R@10=99.22  R@20=99.41
# % reranked: 0.0
# Est. time/query: 0.000s (always-rerank: 3.780s)
#
# === TEST (using p0* from VAL) ===
# [MegaLoc+SuperGlue (sf)] TEST AUPRC - Uncertainty = 0.730
# Random baseline (positive rate) = 0.133
#
# [MegaLoc+SuperGlue (sf) TEST]
# Retrieval-only: R@1=86.70  R@5=89.90  R@10=90.80  R@20=91.30
# Always-rerank:  R@1=85.90  R@5=89.40  R@10=90.40  R@20=91.30
# Adaptive:       R@1=86.70  R@5=89.90  R@10=90.80  R@20=91.30
# % reranked: 0.0
# Est. time/query: 0.000s (always-rerank: 3.780s)

# %%
# !python -u logistic.py \
  --name "MegaLoc+LoFTR(sf)" \
  --train_z_path {path}"/svox_night_train_megaloc/z_data.torch" \
  --train_matches_dir {path}"/svox_night_train_megaloc/preds_loftr" \
  --train2_z_path {path}"/svox_sun_train_megaloc/z_data.torch" \
  --train2_matches_dir {path}"/svox_sun_train_megaloc/preds_loftr" \
  --val_z_path {path}"/sf_val_megaloc/z_data.torch" \
  --val_matches_dir {path}"/sf_val_megaloc/preds_loftr" \
  --test_z_path {path}"/sf_test_megaloc/z_data.torch" \
  --test_matches_dir {path}"/sf_test_megaloc/preds_loftr" \
  --t_rerank 3.78 \
  --t_retrieval 0.0 \
  --plot\
  --plots_dir {path}'/sf_test_megaloc/plots_log_loftr'
# Out:
# === VALIDATION (fixed p0* chosen on VAL) ===
# [MegaLoc+LoFTR(sf)] VAL AUPRC - Uncertainty = 0.446
# Random baseline (positive rate) = 0.027398974102339546
# Chosen cutoff p0*: 0.830  (eps=0.001, based on R@1)
#
# [MegaLoc+LoFTR(sf) VAL]
# Retrieval-only: R@1=97.26  R@5=98.92  R@10=99.22  R@20=99.41
# Always-rerank:  R@1=92.89  R@5=97.34  R@10=98.59  R@20=99.41
# Adaptive:       R@1=97.26  R@5=98.92  R@10=99.22  R@20=99.41
# % reranked: 0.0
# Est. time/query: 0.000s (always-rerank: 3.780s)
#
# === TEST (using p0* from VAL) ===
# [MegaLoc+LoFTR(sf)] TEST AUPRC - Uncertainty = 0.716
# Random baseline (positive rate) = 0.133
#
# [MegaLoc+LoFTR(sf) TEST]
# Retrieval-only: R@1=86.70  R@5=89.90  R@10=90.80  R@20=91.30
# Always-rerank:  R@1=85.60  R@5=89.20  R@10=90.50  R@20=91.30
# Adaptive:       R@1=86.70  R@5=89.90  R@10=90.80  R@20=91.30
# % reranked: 0.0
# Est. time/query: 0.000s (always-rerank: 3.780s)

# %% [markdown]
# # **Tokyo - Test Dataset**

# %%
# !python -u logistic.py \
  --name "NetVLAD+LoFTR (tokyo)" \
  --train_z_path {path}"/svox_night_train_netvlad/z_data.torch" \
  --train_matches_dir {path}"/svox_night_train_netvlad/preds_loftr" \
  --train2_z_path {path}"/svox_sun_train_netvlad/z_data.torch" \
  --train2_matches_dir {path}"/svox_sun_train_netvlad/preds_loftr" \
  --val_z_path {path}"/sf_val_netvlad/z_data.torch" \
  --val_matches_dir {path}"/sf_val_netvlad/preds_loftr" \
  --test_z_path {path}"/tokyo_test_netvlad/z_data.torch" \
  --test_matches_dir {path}"/tokyo_test_netvlad/preds_loftr" \
  --t_rerank 3.78 \
  --t_retrieval 0.0 \
  --plot\
  --plots_dir {path}'/tokyo_test_netvlad/plots_log_loftr'
# Out:
# === VALIDATION (fixed p0* chosen on VAL) ===
# [NetVLAD+LoFTR (tokyo)] VAL AUPRC - Uncertainty = 0.953
# Random baseline (positive rate) = 0.4677843112723633
# Chosen cutoff p0*: 0.020  (eps=0.001, based on R@1)
#
# [NetVLAD+LoFTR (tokyo) VAL]
# Retrieval-only: R@1=53.22  R@5=67.55  R@10=73.33  R@20=78.98
# Always-rerank:  R@1=72.85  R@5=75.82  R@10=77.36  R@20=78.98
# Adaptive:       R@1=72.78  R@5=75.82  R@10=77.36  R@20=78.98
# % reranked: 53.8
# Est. time/query: 2.035s (always-rerank: 3.780s)
#
# === TEST (using p0* from VAL) ===
# [NetVLAD+LoFTR (tokyo)] TEST AUPRC - Uncertainty = 0.965
# Random baseline (positive rate) = 0.5015873015873016
#
# [NetVLAD+LoFTR (tokyo) TEST]
# Retrieval-only: R@1=49.84  R@5=62.54  R@10=70.48  R@20=78.73
# Always-rerank:  R@1=68.57  R@5=72.70  R@10=73.65  R@20=78.73
# Adaptive:       R@1=68.57  R@5=72.70  R@10=73.65  R@20=78.73
# % reranked: 59.7
# Est. time/query: 2.256s (always-rerank: 3.780s)

# %%
# !python -u logistic.py \
  --name "NetVLAD+SuperGlue (Tokyo)" \
  --train_z_path {path}"/svox_night_train_netvlad/z_data.torch" \
  --train_matches_dir {path}"/svox_night_train_netvlad/preds_superglue" \
  --train2_z_path {path}"/svox_sun_train_netvlad/z_data.torch" \
  --train2_matches_dir {path}"/svox_sun_train_netvlad/preds_superglue" \
  --val_z_path {path}"/sf_val_netvlad/z_data.torch" \
  --val_matches_dir {path}"/sf_val_netvlad/preds_superglue" \
  --test_z_path {path}"/tokyo_test_netvlad/z_data.torch" \
  --test_matches_dir {path}"/tokyo_test_netvlad/preds_superglue" \
  --t_rerank 3.78 \
  --t_retrieval 0.0 \
  --plot\
  --plots_dir {path}'/tokyo_test_netvlad/plots_log_superglue'
# Out:
# === VALIDATION (fixed p0* chosen on VAL) ===
# [NetVLAD+SuperGlue (Tokyo)] VAL AUPRC - Uncertainty = 0.950
# Random baseline (positive rate) = 0.4677843112723633
# Chosen cutoff p0*: 0.470  (eps=0.001, based on R@1)
#
# [NetVLAD+SuperGlue (Tokyo) VAL]
# Retrieval-only: R@1=53.22  R@5=67.55  R@10=73.33  R@20=78.98
# Always-rerank:  R@1=70.81  R@5=75.42  R@10=77.10  R@20=78.98
# Adaptive:       R@1=70.89  R@5=75.38  R@10=77.09  R@20=78.98
# % reranked: 55.1
# Est. time/query: 2.085s (always-rerank: 3.780s)
#
# === TEST (using p0* from VAL) ===
# [NetVLAD+SuperGlue (Tokyo)] TEST AUPRC - Uncertainty = 0.983
# Random baseline (positive rate) = 0.5015873015873016
#
# [NetVLAD+SuperGlue (Tokyo) TEST]
# Retrieval-only: R@1=49.84  R@5=62.54  R@10=70.48  R@20=78.73
# Always-rerank:  R@1=69.21  R@5=72.38  R@10=74.60  R@20=78.73
# Adaptive:       R@1=69.21  R@5=72.38  R@10=74.60  R@20=78.73
# % reranked: 60.0
# Est. time/query: 2.268s (always-rerank: 3.780s)

# %%
# !python -u logistic.py \
  --name "MegaLoc+LoFTR(tokyo)" \
  --train_z_path {path}"/svox_night_train_megaloc/z_data.torch" \
  --train_matches_dir {path}"/svox_night_train_megaloc/preds_loftr" \
  --train2_z_path {path}"/svox_sun_train_megaloc/z_data.torch" \
  --train2_matches_dir {path}"/svox_sun_train_megaloc/preds_loftr" \
  --val_z_path {path}"/sf_val_megaloc/z_data.torch" \
  --val_matches_dir {path}"/sf_val_megaloc/preds_loftr" \
  --test_z_path {path}"/tokyo_test_megaloc/z_data.torch" \
  --test_matches_dir {path}"/tokyo_test_megaloc/preds_loftr" \
  --t_rerank 3.78 \
  --t_retrieval 0.0 \
  --plot\
  --plots_dir {path}'/tokyo_test_megaloc/plots_log_loftr'
# Out:
# === VALIDATION (fixed p0* chosen on VAL) ===
# [MegaLoc+LoFTR(tokyo)] VAL AUPRC - Uncertainty = 0.446
# Random baseline (positive rate) = 0.027398974102339546
# Chosen cutoff p0*: 0.830  (eps=0.001, based on R@1)
#
# [MegaLoc+LoFTR(tokyo) VAL]
# Retrieval-only: R@1=97.26  R@5=98.92  R@10=99.22  R@20=99.41
# Always-rerank:  R@1=92.89  R@5=97.34  R@10=98.59  R@20=99.41
# Adaptive:       R@1=97.26  R@5=98.92  R@10=99.22  R@20=99.41
# % reranked: 0.0
# Est. time/query: 0.000s (always-rerank: 3.780s)
#
# === TEST (using p0* from VAL) ===
# [MegaLoc+LoFTR(tokyo)] TEST AUPRC - Uncertainty = 0.465
# Random baseline (positive rate) = 0.050793650793650794
#
# [MegaLoc+LoFTR(tokyo) TEST]
# Retrieval-only: R@1=94.92  R@5=97.46  R@10=98.41  R@20=99.05
# Always-rerank:  R@1=94.92  R@5=97.46  R@10=98.73  R@20=99.05
# Adaptive:       R@1=94.92  R@5=97.46  R@10=98.41  R@20=99.05
# % reranked: 0.0
# Est. time/query: 0.000s (always-rerank: 3.780s)

# %%
# !python -u logistic.py \
  --name "MegaLoc+SuperGlue (tokyo)" \
  --train_z_path {path}"/svox_night_train_megaloc/z_data.torch" \
  --train_matches_dir {path}"/svox_night_train_megaloc/preds_superglue" \
  --train2_z_path {path}"/svox_sun_train_megaloc/z_data.torch" \
  --train2_matches_dir {path}"/svox_sun_train_megaloc/preds_superglue" \
  --val_z_path {path}"/sf_val_megaloc/z_data.torch" \
  --val_matches_dir {path}"/sf_val_megaloc/preds_superglue" \
  --test_z_path {path}"/tokyo_test_megaloc/z_data.torch" \
  --test_matches_dir {path}"/tokyo_test_megaloc/preds_superglue" \
  --t_rerank 3.78 \
  --t_retrieval 0.0 \
  --plot\
  --plots_dir {path}'/tokyo_test_megaloc/plots_log_superglue'
# Out:
# === VALIDATION (fixed p0* chosen on VAL) ===
# [MegaLoc+SuperGlue (tokyo)] VAL AUPRC - Uncertainty = 0.426
# Random baseline (positive rate) = 0.027398974102339546
# Chosen cutoff p0*: 0.920  (eps=0.001, based on R@1)
#
# [MegaLoc+SuperGlue (tokyo) VAL]
# Retrieval-only: R@1=97.26  R@5=98.92  R@10=99.22  R@20=99.41
# Always-rerank:  R@1=91.33  R@5=97.72  R@10=98.87  R@20=99.41
# Adaptive:       R@1=97.26  R@5=98.92  R@10=99.22  R@20=99.41
# % reranked: 0.0
# Est. time/query: 0.000s (always-rerank: 3.780s)
#
# === TEST (using p0* from VAL) ===
# [MegaLoc+SuperGlue (tokyo)] TEST AUPRC - Uncertainty = 0.516
# Random baseline (positive rate) = 0.050793650793650794
#
# [MegaLoc+SuperGlue (tokyo) TEST]
# Retrieval-only: R@1=94.92  R@5=97.46  R@10=98.41  R@20=99.05
# Always-rerank:  R@1=93.65  R@5=97.46  R@10=98.73  R@20=99.05
# Adaptive:       R@1=94.92  R@5=97.46  R@10=98.41  R@20=99.05
# % reranked: 0.0
# Est. time/query: 0.000s (always-rerank: 3.780s)

# %% [markdown]
# # **Svox_night - Test Dataset**

# %%
# !python -u logistic.py \
  --name "NetVLAD+LoFTR (svox_night)" \
  --train_z_path {path}"/svox_night_train_netvlad/z_data.torch" \
  --train_matches_dir {path}"/svox_night_train_netvlad/preds_loftr" \
  --train2_z_path {path}"/svox_sun_train_netvlad/z_data.torch" \
  --train2_matches_dir {path}"/svox_sun_train_netvlad/preds_loftr" \
  --val_z_path {path}"/sf_val_netvlad/z_data.torch" \
  --val_matches_dir {path}"/sf_val_netvlad/preds_loftr" \
  --test_z_path {path}"/svox_night_test_netvlad/z_data.torch" \
  --test_matches_dir {path}"/svox_night_test_netvlad/preds_loftr" \
  --t_rerank 3.78 \
  --t_retrieval 0.0 \
  --plot\
  --plots_dir {path}'/svox_night_test_netvlad/plots_log_loftr'
# Out:
# === VALIDATION (fixed p0* chosen on VAL) ===
# [NetVLAD+LoFTR (svox_night)] VAL AUPRC - Uncertainty = 0.953
# Random baseline (positive rate) = 0.4677843112723633
# Chosen cutoff p0*: 0.020  (eps=0.001, based on R@1)
#
# [NetVLAD+LoFTR (svox_night) VAL]
# Retrieval-only: R@1=53.22  R@5=67.55  R@10=73.33  R@20=78.98
# Always-rerank:  R@1=72.85  R@5=75.82  R@10=77.36  R@20=78.98
# Adaptive:       R@1=72.78  R@5=75.82  R@10=77.36  R@20=78.98
# % reranked: 53.8
# Est. time/query: 2.035s (always-rerank: 3.780s)
#
# === TEST (using p0* from VAL) ===
# [NetVLAD+LoFTR (svox_night)] TEST AUPRC - Uncertainty = 0.998
# Random baseline (positive rate) = 0.9198055893074119
#
# [NetVLAD+LoFTR (svox_night) TEST]
# Retrieval-only: R@1=8.02  R@5=17.38  R@10=23.09  R@20=29.65
# Always-rerank:  R@1=25.64  R@5=27.83  R@10=28.55  R@20=29.65
# Adaptive:       R@1=25.64  R@5=27.70  R@10=28.43  R@20=29.65
# % reranked: 93.8
# Est. time/query: 3.546s (always-rerank: 3.780s)

# %%
# !python -u logistic.py \
  --name "NetVLAD+SuperGlue (svox_night)" \
  --train_z_path {path}"/svox_night_train_netvlad/z_data.torch" \
  --train_matches_dir {path}"/svox_night_train_netvlad/preds_superglue" \
  --train2_z_path {path}"/svox_sun_train_netvlad/z_data.torch" \
  --train2_matches_dir {path}"/svox_sun_train_netvlad/preds_superglue" \
  --val_z_path {path}"/sf_val_netvlad/z_data.torch" \
  --val_matches_dir {path}"/sf_val_netvlad/preds_superglue" \
  --test_z_path {path}"/svox_night_test_netvlad/z_data.torch" \
  --test_matches_dir {path}"/svox_night_test_netvlad/preds_superglue" \
  --t_rerank 3.78 \
  --t_retrieval 0.0 \
  --plot\
  --plots_dir {path}'/svox_night_test_netvlad/plots_log_superglue'
# Out:
# === VALIDATION (fixed p0* chosen on VAL) ===
# [NetVLAD+SuperGlue (svox_night)] VAL AUPRC - Uncertainty = 0.950
# Random baseline (positive rate) = 0.4677843112723633
# Chosen cutoff p0*: 0.470  (eps=0.001, based on R@1)
#
# [NetVLAD+SuperGlue (svox_night) VAL]
# Retrieval-only: R@1=53.22  R@5=67.55  R@10=73.33  R@20=78.98
# Always-rerank:  R@1=70.81  R@5=75.42  R@10=77.10  R@20=78.98
# Adaptive:       R@1=70.89  R@5=75.38  R@10=77.09  R@20=78.98
# % reranked: 55.1
# Est. time/query: 2.085s (always-rerank: 3.780s)
#
# === TEST (using p0* from VAL) ===
# [NetVLAD+SuperGlue (svox_night)] TEST AUPRC - Uncertainty = 0.997
# Random baseline (positive rate) = 0.9198055893074119
#
# [NetVLAD+SuperGlue (svox_night) TEST]
# Retrieval-only: R@1=8.02  R@5=17.38  R@10=23.09  R@20=29.65
# Always-rerank:  R@1=24.54  R@5=26.97  R@10=27.95  R@20=29.65
# Adaptive:       R@1=24.54  R@5=26.97  R@10=27.95  R@20=29.65
# % reranked: 92.1
# Est. time/query: 3.481s (always-rerank: 3.780s)

# %%
# !python -u logistic.py \
  --name "MegaLoc+SuperGlue (svox_night)" \
  --train_z_path {path}"/svox_night_train_megaloc/z_data.torch" \
  --train_matches_dir {path}"/svox_night_train_megaloc/preds_superglue" \
  --train2_z_path {path}"/svox_sun_train_megaloc/z_data.torch" \
  --train2_matches_dir {path}"/svox_sun_train_megaloc/preds_superglue" \
  --val_z_path {path}"/sf_val_megaloc/z_data.torch" \
  --val_matches_dir {path}"/sf_val_megaloc/preds_superglue" \
  --test_z_path {path}"/svox_night_test_megaloc/z_data.torch" \
  --test_matches_dir {path}"/svox_night_test_megaloc/preds_superglue" \
  --t_rerank 3.78 \
  --t_retrieval 0.0 \
  --plot\
  --plots_dir {path}'/svox_night_test_megaloc/plots_log_superglue'
# Out:
# === VALIDATION (fixed p0* chosen on VAL) ===
# [MegaLoc+SuperGlue (svox_night)] VAL AUPRC - Uncertainty = 0.426
# Random baseline (positive rate) = 0.027398974102339546
# Chosen cutoff p0*: 0.920  (eps=0.001, based on R@1)
#
# [MegaLoc+SuperGlue (svox_night) VAL]
# Retrieval-only: R@1=97.26  R@5=98.92  R@10=99.22  R@20=99.41
# Always-rerank:  R@1=91.33  R@5=97.72  R@10=98.87  R@20=99.41
# Adaptive:       R@1=97.26  R@5=98.92  R@10=99.22  R@20=99.41
# % reranked: 0.0
# Est. time/query: 0.000s (always-rerank: 3.780s)
#
# === TEST (using p0* from VAL) ===
# [MegaLoc+SuperGlue (svox_night)] TEST AUPRC - Uncertainty = 0.548
# Random baseline (positive rate) = 0.04860267314702309
#
# [MegaLoc+SuperGlue (svox_night) TEST]
# Retrieval-only: R@1=95.14  R@5=98.06  R@10=98.78  R@20=99.15
# Always-rerank:  R@1=90.52  R@5=97.45  R@10=98.42  R@20=99.15
# Adaptive:       R@1=95.14  R@5=98.06  R@10=98.78  R@20=99.15
# % reranked: 0.0
# Est. time/query: 0.000s (always-rerank: 3.780s)

# %%
# !python -u logistic.py \
  --name "MegaLoc+LoFTR(svox_night)" \
  --train_z_path {path}"/svox_night_train_megaloc/z_data.torch" \
  --train_matches_dir {path}"/svox_night_train_megaloc/preds_loftr" \
  --train2_z_path {path}"/svox_sun_train_megaloc/z_data.torch" \
  --train2_matches_dir {path}"/svox_sun_train_megaloc/preds_loftr" \
  --val_z_path {path}"/sf_val_megaloc/z_data.torch" \
  --val_matches_dir {path}"/sf_val_megaloc/preds_loftr" \
  --test_z_path {path}"/svox_night_test_megaloc/z_data.torch" \
  --test_matches_dir {path}"/svox_night_test_megaloc/preds_loftr" \
  --t_rerank 3.78 \
  --t_retrieval 0.0 \
  --plot\
  --plots_dir {path}'/svox_night_test_megaloc/plots_log_loftr'
# Out:
# === VALIDATION (fixed p0* chosen on VAL) ===
# [MegaLoc+LoFTR(svox_night)] VAL AUPRC - Uncertainty = 0.446
# Random baseline (positive rate) = 0.027398974102339546
# Chosen cutoff p0*: 0.830  (eps=0.001, based on R@1)
#
# [MegaLoc+LoFTR(svox_night) VAL]
# Retrieval-only: R@1=97.26  R@5=98.92  R@10=99.22  R@20=99.41
# Always-rerank:  R@1=92.89  R@5=97.34  R@10=98.59  R@20=99.41
# Adaptive:       R@1=97.26  R@5=98.92  R@10=99.22  R@20=99.41
# % reranked: 0.0
# Est. time/query: 0.000s (always-rerank: 3.780s)
#
# === TEST (using p0* from VAL) ===
# [MegaLoc+LoFTR(svox_night)] TEST AUPRC - Uncertainty = 0.421
# Random baseline (positive rate) = 0.04860267314702309
#
# [MegaLoc+LoFTR(svox_night) TEST]
# Retrieval-only: R@1=95.14  R@5=98.06  R@10=98.78  R@20=99.15
# Always-rerank:  R@1=92.47  R@5=98.06  R@10=98.78  R@20=99.15
# Adaptive:       R@1=95.14  R@5=98.06  R@10=98.78  R@20=99.15
# % reranked: 0.0
# Est. time/query: 0.000s (always-rerank: 3.780s)

# %% [markdown]
# # **Svox_sun Test Dataset**

# %%
# !python -u logistic.py \
  --name "NetVLAD+LoFTR (svox_sun)" \
  --train_z_path {path}"/svox_night_train_netvlad/z_data.torch" \
  --train_matches_dir {path}"/svox_night_train_netvlad/preds_loftr" \
  --train2_z_path {path}"/svox_sun_train_netvlad/z_data.torch" \
  --train2_matches_dir {path}"/svox_sun_train_netvlad/preds_loftr" \
  --val_z_path {path}"/sf_val_netvlad/z_data.torch" \
  --val_matches_dir {path}"/sf_val_netvlad/preds_loftr" \
  --test_z_path {path}"/svox_sun_test_netvlad/z_data.torch" \
  --test_matches_dir {path}"/svox_sun_test_netvlad/preds_loftr" \
  --t_rerank 3.78 \
  --t_retrieval 0.0 \
  --plot\
  --plots_dir {path}'/svox_sun_test_netvlad/plots_log_loftr'
# Out:
# === VALIDATION (fixed p0* chosen on VAL) ===
# [NetVLAD+LoFTR (svox_sun)] VAL AUPRC - Uncertainty = 0.953
# Random baseline (positive rate) = 0.4677843112723633
# Chosen cutoff p0*: 0.020  (eps=0.001, based on R@1)
#
# [NetVLAD+LoFTR (svox_sun) VAL]
# Retrieval-only: R@1=53.22  R@5=67.55  R@10=73.33  R@20=78.98
# Always-rerank:  R@1=72.85  R@5=75.82  R@10=77.36  R@20=78.98
# Adaptive:       R@1=72.78  R@5=75.82  R@10=77.36  R@20=78.98
# % reranked: 53.8
# Est. time/query: 2.035s (always-rerank: 3.780s)
#
# === TEST (using p0* from VAL) ===
# [NetVLAD+LoFTR (svox_sun)] TEST AUPRC - Uncertainty = 0.995
# Random baseline (positive rate) = 0.6463700234192038
#
# [NetVLAD+LoFTR (svox_sun) TEST]
# Retrieval-only: R@1=35.36  R@5=52.69  R@10=58.78  R@20=65.81
# Always-rerank:  R@1=61.48  R@5=63.47  R@10=64.52  R@20=65.81
# Adaptive:       R@1=61.12  R@5=63.47  R@10=64.52  R@20=65.81
# % reranked: 67.8
# Est. time/query: 2.563s (always-rerank: 3.780s)

# %%
# !python -u logistic.py \
  --name "NetVLAD+SuperGlue (svox_sun)" \
  --train_z_path {path}"/svox_night_train_netvlad/z_data.torch" \
  --train_matches_dir {path}"/svox_night_train_netvlad/preds_superglue" \
  --train2_z_path {path}"/svox_sun_train_netvlad/z_data.torch" \
  --train2_matches_dir {path}"/svox_sun_train_netvlad/preds_superglue" \
  --val_z_path {path}"/sf_val_netvlad/z_data.torch" \
  --val_matches_dir {path}"/sf_val_netvlad/preds_superglue" \
  --test_z_path {path}"/svox_sun_test_netvlad/z_data.torch" \
  --test_matches_dir {path}"/svox_sun_test_netvlad/preds_superglue" \
  --t_rerank 3.78 \
  --t_retrieval 0.0 \
  --plot\
  --plots_dir {path}'/svox_sun_test_netvlad/plots_log_superglue'
# Out:
# === VALIDATION (fixed p0* chosen on VAL) ===
# [NetVLAD+SuperGlue (svox_sun)] VAL AUPRC - Uncertainty = 0.950
# Random baseline (positive rate) = 0.4677843112723633
# Chosen cutoff p0*: 0.470  (eps=0.001, based on R@1)
#
# [NetVLAD+SuperGlue (svox_sun) VAL]
# Retrieval-only: R@1=53.22  R@5=67.55  R@10=73.33  R@20=78.98
# Always-rerank:  R@1=70.81  R@5=75.42  R@10=77.10  R@20=78.98
# Adaptive:       R@1=70.89  R@5=75.38  R@10=77.09  R@20=78.98
# % reranked: 55.1
# Est. time/query: 2.085s (always-rerank: 3.780s)
#
# === TEST (using p0* from VAL) ===
# [NetVLAD+SuperGlue (svox_sun)] TEST AUPRC - Uncertainty = 0.992
# Random baseline (positive rate) = 0.6463700234192038
#
# [NetVLAD+SuperGlue (svox_sun) TEST]
# Retrieval-only: R@1=35.36  R@5=52.69  R@10=58.78  R@20=65.81
# Always-rerank:  R@1=60.66  R@5=63.23  R@10=64.40  R@20=65.81
# Adaptive:       R@1=59.48  R@5=63.00  R@10=64.17  R@20=65.81
# % reranked: 64.3
# Est. time/query: 2.430s (always-rerank: 3.780s)

# %%
# !python -u logistic.py \
  --name "MegaLoc+SuperGlue (svox_sun)" \
  --train_z_path {path}"/svox_night_train_megaloc/z_data.torch" \
  --train_matches_dir {path}"/svox_night_train_megaloc/preds_superglue" \
  --train2_z_path {path}"/svox_sun_train_megaloc/z_data.torch" \
  --train2_matches_dir {path}"/svox_sun_train_megaloc/preds_superglue" \
  --val_z_path {path}"/sf_val_megaloc/z_data.torch" \
  --val_matches_dir {path}"/sf_val_megaloc/preds_superglue" \
  --test_z_path {path}"/svox_sun_test_megaloc/z_data.torch" \
  --test_matches_dir {path}"/svox_sun_test_megaloc/preds_superglue" \
  --t_rerank 3.78 \
  --t_retrieval 0.0 \
  --plot\
  --plots_dir {path}'/svox_sun_test_megaloc/plots_log_superglue'
# Out:
# === VALIDATION (fixed p0* chosen on VAL) ===
# [MegaLoc+SuperGlue (svox_sun)] VAL AUPRC - Uncertainty = 0.426
# Random baseline (positive rate) = 0.027398974102339546
# Chosen cutoff p0*: 0.920  (eps=0.001, based on R@1)
#
# [MegaLoc+SuperGlue (svox_sun) VAL]
# Retrieval-only: R@1=97.26  R@5=98.92  R@10=99.22  R@20=99.41
# Always-rerank:  R@1=91.33  R@5=97.72  R@10=98.87  R@20=99.41
# Adaptive:       R@1=97.26  R@5=98.92  R@10=99.22  R@20=99.41
# % reranked: 0.0
# Est. time/query: 0.000s (always-rerank: 3.780s)
#
# === TEST (using p0* from VAL) ===
# [MegaLoc+SuperGlue (svox_sun)] TEST AUPRC - Uncertainty = 0.225
# Random baseline (positive rate) = 0.0351288056206089
#
# [MegaLoc+SuperGlue (svox_sun) TEST]
# Retrieval-only: R@1=96.49  R@5=99.41  R@10=99.65  R@20=99.65
# Always-rerank:  R@1=94.26  R@5=98.95  R@10=99.65  R@20=99.65
# Adaptive:       R@1=96.49  R@5=99.41  R@10=99.65  R@20=99.65
# % reranked: 0.0
# Est. time/query: 0.000s (always-rerank: 3.780s)

# %%
# !python -u logistic.py \
  --name "MegaLoc+LoFTR(svox_sun)" \
  --train_z_path {path}"/svox_night_train_megaloc/z_data.torch" \
  --train_matches_dir {path}"/svox_night_train_megaloc/preds_loftr" \
  --train2_z_path {path}"/svox_sun_train_megaloc/z_data.torch" \
  --train2_matches_dir {path}"/svox_sun_train_megaloc/preds_loftr" \
  --val_z_path {path}"/sf_val_megaloc/z_data.torch" \
  --val_matches_dir {path}"/sf_val_megaloc/preds_loftr" \
  --test_z_path {path}"/svox_sun_test_megaloc/z_data.torch" \
  --test_matches_dir {path}"/svox_sun_test_megaloc/preds_loftr" \
  --t_rerank 3.78 \
  --t_retrieval 0.0 \
  --plot\
  --plots_dir {path}'/svox_sun_test_megaloc/plots_log_loftr'
# Out:
# === VALIDATION (fixed p0* chosen on VAL) ===
# [MegaLoc+LoFTR(svox_sun)] VAL AUPRC - Uncertainty = 0.446
# Random baseline (positive rate) = 0.027398974102339546
# Chosen cutoff p0*: 0.830  (eps=0.001, based on R@1)
#
# [MegaLoc+LoFTR(svox_sun) VAL]
# Retrieval-only: R@1=97.26  R@5=98.92  R@10=99.22  R@20=99.41
# Always-rerank:  R@1=92.89  R@5=97.34  R@10=98.59  R@20=99.41
# Adaptive:       R@1=97.26  R@5=98.92  R@10=99.22  R@20=99.41
# % reranked: 0.0
# Est. time/query: 0.000s (always-rerank: 3.780s)
#
# === TEST (using p0* from VAL) ===
# [MegaLoc+LoFTR(svox_sun)] TEST AUPRC - Uncertainty = 0.263
# Random baseline (positive rate) = 0.0351288056206089
#
# [MegaLoc+LoFTR(svox_sun) TEST]
# Retrieval-only: R@1=96.49  R@5=99.41  R@10=99.65  R@20=99.65
# Always-rerank:  R@1=96.72  R@5=99.41  R@10=99.41  R@20=99.65
# Adaptive:       R@1=96.49  R@5=99.41  R@10=99.65  R@20=99.65
# % reranked: 0.1
# Est. time/query: 0.004s (always-rerank: 3.780s)
